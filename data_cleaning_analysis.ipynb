# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('automobileEDA.csv')
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
import seaborn as sns
sns.set()

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df['peak-rpm'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Examining the correlation between all the independent variables

# %%
df.corr()
# Out:
# /var/folders/82/3xtnb7x55vn8fnk09l6kq3qm0000gn/T/ipykernel_18425/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# ...

# %% [markdown]
# Calculating the correlation between bore, stroke and compression ration

# %%
df[['bore','stroke','compression-ratio']].corr()
# Out:
#                        bore    stroke  compression-ratio
# bore               1.000000 -0.055390           0.001263
# stroke            -0.055390  1.000000           0.187923
# compression-ratio  0.001263  0.187923           1.000000

# %% [markdown]
# Determining if relationship between variables and price are linear

# %%
sns.regplot(x='engine-size',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# There exists a strong positive correlation betwen engine size and price

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %%
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# Relatively strong negative linear relationship between highway mpg and price as shown by the graph

# %%
df[['stroke','price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.regplot(x='stroke',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='price'>

# %% [markdown]
# No definitive relationship between engine stroke and price

# %% [markdown]
# Graphical representaion of catagorical data

# %%
sns.boxplot(x='body-style',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x='drive-wheels',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# There is a greater chance for RWD vehicles to be the most expensive

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %% [markdown]
# valu_counts method to count to amount of different elements in a PD SERIES

# %%
df['body-style'].value_counts()
# Out:
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %% [markdown]
# to_frame method to convert the series into a dataframe

# %%
df['body-style'].value_counts().to_frame()
# Out:
#              body-style
# sedan                94
# hatchback            68
# wagon                25
# hardtop               8
# convertible           6

# %% [markdown]
# Creating a dataframe of the amount of vehicles with different drivetrain

# %%
drive_wheel_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheel_counts.rename({'drive-wheels':'value-counts'},inplace=True)
drive_wheel_counts
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheel_counts.index.name='drive-wheels'
drive_wheel_counts
# Out:
#               drive-wheels
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %%
engline_location = df['engine-location'].value_counts().to_frame()
engline_location.rename({'engine-location':'value-counts'},inplace=True)
engline_location
# Out:
#        engine-location
# front              198
# rear                 3

# %%
engline_location.index.name='drive'
engline_location
# Out:
#        engine-location
# drive
# front              198
# rear                 3

# %% [markdown]
# Engine count heavily skewed to fwd so it would not be a good variable to determine price

# %%
df_group_one = df[['drive-wheels','body-style','price']]

# %% [markdown]
# Using the groupby method to group the catagorical variables

# %%
df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean()
df_group_one
# Out:
# /var/folders/82/3xtnb7x55vn8fnk09l6kq3qm0000gn/T/ipykernel_18425/3352877039.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean()
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %% [markdown]
# Further confirmation ƒrom the box plot of rwd vehicles costing more than the other types of vehicles

# %% [markdown]
# Grouping by multiple groups gives...

# %%
df_gptest = df[['drive-wheels', 'body-style','price']]

# %%
df_gptest = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
df_gptest
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# The pivot method can be used to convert the previous table into a pivot table

# %%
grouped_pivot = df_gptest.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot = grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
groupby_2 = df[['body-style','price']]
groupby_2 = groupby_2.groupby(['body-style'], as_index=False).mean()
groupby_2
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %% [markdown]
# Creating a heatmap of the pivot table

# %%
plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()
# Out:
# /var/folders/82/3xtnb7x55vn8fnk09l6kq3qm0000gn/T/ipykernel_18425/1083060074.py:1: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.pcolor(grouped_pivot, cmap='RdBu')
# /var/folders/82/3xtnb7x55vn8fnk09l6kq3qm0000gn/T/ipykernel_18425/1083060074.py:2: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
from scipy import stats

# %%
df[['wheel-base','price']].corr()
# Out:
#             wheel-base     price
# wheel-base    1.000000  0.584642
# price         0.584642  1.000000

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'],df['price'])
print("The pearson coef is {} and its p-value is {}".format(pearson_coef,p_value))
# Out:
# The pearson coef is 0.5846418222655083 and its p-value is 8.076488270732873e-20

# %%
stats.pearsonr(df['price'],df['horsepower'])
# Out:
# (0.8095745670036555, 6.369057428261186e-48)

# %% [markdown]
# Large pearson coefficient, and p-value very close to 0. This implies a positive linear correlation between price and horsepower and horsepower is statistically significant in determining the price.

# %%
pearson_coef, p_value = stats.pearsonr(df['bore'], df['price'])
print("The pearson coef is {} and its p-value is {}.".format(pearson_coef, p_value))
# Out:
# The pearson coef is 0.5431553832626606 and its p-value is 8.049189483935032e-17.

# %% [markdown]
# While statistically significant, there is not a solid relationship between boresize and price
